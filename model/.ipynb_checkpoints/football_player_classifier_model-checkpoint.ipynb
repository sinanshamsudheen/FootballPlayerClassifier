# %%
import cv2
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
img=cv2.imread('./test_images/iniesta.jpg')
img.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img)

# %%
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (183, 275)

# %%
gray
# Out:
# array([[57, 57, 57, ..., 46, 46, 46],
#        [57, 57, 57, ..., 46, 46, 47],
#        [57, 57, 57, ..., 46, 47, 47],
#        ...,
#        [90, 90, 90, ..., 67, 67, 66],
#        [92, 92, 92, ..., 66, 66, 66],
#        [93, 93, 93, ..., 66, 66, 66]], shape=(183, 275), dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade=cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eyes_cascade=cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces=face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[71, 21, 81, 81]], dtype=int32)

# %%
(x,y,w,h)=faces[0]
x,y,w,h
# Out:
# (np.int32(71), np.int32(21), np.int32(81), np.int32(81))

# %%
face_img=cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)
